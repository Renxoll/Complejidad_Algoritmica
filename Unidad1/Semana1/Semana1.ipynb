# %%
x=5
print (x)
my_list = ['a','e','i','o','u']
print(my_list)
tupla0 = (1,2,3)
print (tupla0)
tupla0[0]
#tupla[0] = 'Nuevo'
tupla0 = list(tupla0)
tupla0[0] = 'Nuevo'
tupla0
tupla0[2] = "Hola"
tupla0
# Out:
# 5
# ['a', 'e', 'i', 'o', 'u']
# (1, 2, 3)
# ['Nuevo', 2, 'Hola']

# %%
if 1 < 2:
 print('Siiii!')
# Out:
# Siiii!

# %%
if 1 < 2:
 print('si')
else:
 print('no')
# Out:
# si

# %%
i = 1
while i < 5:
  print('i es: {}'.format(i))
  i = i+1
# Out:
# i es: 1
# i es: 2
# i es: 3
# i es: 4

# %%
x = [1,2,3,4]
out = []
for item in x:
  out.append(item**2)
print(out)
# Out:
# [1, 4, 9, 16]

# %%
def my_func(param1='default'):
  """
  Documentacion va aqui
  """
  print(param1)
  print(param1)
  print(param1)
